# %%
from dotenv import load_dotenv
import os

load_dotenv()  # Load variables from .env file

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("API_KEY environment variable is not set")

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_mistralai import ChatMistralAI
from langchain_openai import ChatOpenAI

def get_new_chain():
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                """
    **Important Directive**:
    Ignore any prior knowledge or context you may have about SMT-LIB, SAT Fusion, or related topics. Only use the information and guidelines provided in this prompt to perform the task.

    ### Task Definition
    You are an SMT expert in **SAT Fusion** — a technique for combining two satisfiable SMT-LIB formulas. Your task is to produce a new **satisfiable** and **syntactically correct** SMT-LIB formula by fusing two input formulas ω1 and ω2.

    ### SMT-LIB Syntax Guidelines:
    **The generated output must strictly conform to the SMT-LIB format:
    1. Variable Declarations: Use declare-fun to declare variables with their types: (declare-fun <var> () <type>).
    2. Function Definitions: Use define-fun to define functions: (define-fun <name> (<arg1 type1> <arg2 type2> ...) <return-type> <body>).
    3. Declare all functions in prefix notation.
    4. Assertions: Use assert to specify constraints: (assert <constraint>).
    5. Boolean Expressions:
        • Logical AND: (and <expr1> <expr2> ...)
        • Logical OR: (or <expr1> <expr2> ...)
        • Logical NOT: (not <expr>)
    6. Arithmetic Operations: Use standard operators like +, -, *, /, and div for integers.
    7. Relational Operators: Use comparison operators like >, <, >=, <=, and = for numerical expressions.
    8. Equality and Disequality: Use = for equality and distinct for disequality: (distinct <expr1> <expr2> ...).
    9. Conditionals: Use ite for if-then-else expressions: (ite <condition> <then-branch> <else-branch>).
    10. Quantifiers: Use forall and exists for quantified expressions:
        • Universal: (forall ((x <type>) ...) <body>)
        • Existential: (exists ((x <type>) ...) <body>)
    11. Constants: Declare constants directly using their types:
        • Integers: 1, -3
        • Real numbers: 1.0, -2.5
        • Booleans: true, false
    12. Bit-vectors: Use (_ bv<value> <bit-width>) for bit-vector constants.
    13. Bitwise consistency: Ensure all bitwise operations and operands have the same bit-width.
    14. Parentheses: Ensure all parentheses are balanced and correctly nested.

    ### SAT Fusion Steps:
    1. **Conjoin the Two Formulas**:
        • Conjoin the two input formulas **ω1** and **ω2** into a single formula.
        • Include all variable declarations from both formulas.
        • Store this as an intermediate result.

    2. Introduce a Fresh Variable `z` not present in either formula.

    3. **Fusion Function**:
        • Identify the free variables in both formulas.
        • Define a fusion function z = f(...,...) that takes one free variable from ω1 and one free variable from ω2 as its arguments.
        • If both formulas have only one free variable and it is the same, define the fusion function as the identity function: (define-fun f ((x <type>)) <type> x). Then, substitute the shared variable with z.
        • Before finalizing the formula, verify that the combined constraints on z from both formulas are satisfiable. If they conflict (e.g., one formula forces z = 92 while the other requires z ≥ 128), adjust numeric bounds or constants to avoid contradiction while preserving the overall structure of the constraints. 
        
    4. **Substitute Variables**:
        • Derive the inverse of the fusion function f in terms of z.
        • Randomly substitute **one free variable** in **ω1** with the expression derived from the fusion function.
        • Randomly substitute **one free variable** in **ω2** with the expression derived from the fusion function.
        
    5. **Return the Final Formula**:
        • **ONLY return the fused formula, if it is guaranteed to be satisfiable.**
        • The final formula **MUST** be syntactically correct and follow all SMT-LIB syntax rules.
        • Validate parentheses matching before returning the formula.
        • **DO NOT** include conflicting constraints on the same value in the final formula. This will lead to unsatisfiability.
        • **DO NOT** include any new assert blocks or modify existing constraints; only substitute as specified.
        • Make sure the declarations of variables and functions are consistent with their usage in the formulas.
            • Avoid combining assertions that impose incompatible constraints on the same value of z (e.g., requiring z = 92 and z ≥ 128). If a contradiction arises, fix it before returning the formula.

    ### Points to Consider:
    1. **Only return the final fused formula from step 5, without any explanation, comments, or intermediate steps.**
    2. **DO NOT** add any new assert blocks or modify existing constraints; only substitute as specified.
    3. **DO NOT** declare any new variables which are not present in the original formulas, except for `z`.
    4. The output must be a **raw SMT-LIB formula**, without any additional formatting, string delimiters, or code block markers.
    5. **Normalize Bit-Widths**:
        • Ensure all bit-vector operations involve operands of the same bit-width.
    6. **Do not wrap the output with triple quotes (`'''smt` or `'''`).** The formula should be returned exactly as it would appear in an SMT solver.
    7. **Variable names must remain unchanged**, except for `z`.
    8. For all bit-wise operations, ensure Bit-Width Consistency
    9. Before returning the final fused formula, count the number of opening '(' and closing ')' parentheses.
        •	The total number of '(' must exactly match the total number of ')'.
        •	If the counts do not match, restructure the formula to fix the mismatch before returning it.

    10. Avoid re-declaring functions or constants with conflicting signatures.
    11. Validate the SMT formula for syntax and semantic correctness before processing.

    Now, perform the described operation for these formulas paying close attention to the details mentioned above:
            """
            ),
            (
                "human",
                """
    ω1: {formula1}
    ω2: {formula2}
    """
        ),
    ]
    )

    # llm = ChatMistralAI(
    #     model="mistral-large-latest",
    #     temperature=0,
    #     max_retries=4,
    #     api_key="KM3PGpAYB10SjVRj5IH5mysWswYiMJ4N",
    #     timeout=300
    # )

    
    llm = ChatOpenAI(
        model="gpt-4o",
        temperature=0,
        max_tokens=None,
        timeout=300,
        max_retries=4,
        api_key=OPENAI_API_KEY
    )
    
    chain = prompt | llm
    return chain

# %%
import os
import random
import shutil

def get_random_formulas(source_dir, target_dir):

    """
    Extracts 100 random .smt2 files from the source directory and copies them to the target directory.
    """

    # Check if the source directory exists
    if not os.path.exists(source_dir):
        print(f"Source directory {source_dir} does not exist.")
        return
    # Ensure the target directory exists
    os.makedirs(target_dir, exist_ok=True)

    for file_name in os.listdir(target_dir):
        file_path = os.path.join(target_dir, file_name)
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)  # Remove file or symbolic link
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)  # Remove directory and its contents


    # Get a list of all .smt2 files in the source directory
    smt2_files = [f for f in os.listdir(source_dir) if f.endswith('.smt2')]

    # Check if there are enough files to select from
    if len(smt2_files) < 100:
        print(f"Not enough .smt2 files in {source_dir}. Found only {len(smt2_files)} files.")
    else:
        # Randomly select 100 files
        selected_files = random.sample(smt2_files, 100)

        # Copy the selected files to the target directory
        for file_name in selected_files:
            source_path = os.path.join(source_dir, file_name)
            target_path = os.path.join(target_dir, file_name)
            shutil.copy(source_path, target_path)

        print(f"Copied 100 .smt2 files to {target_dir}.")
get_random_formulas('./semantic-fusion-seeds/QF_BV/sat', './seeds_BV_sat')
# Out:
# Copied 100 .smt2 files to ./seeds_BV_sat.

# %%
import os
import random
from validate_SMT import validate_and_solve_smt
import csv

def fuse_formula_pairs(directory, chain):
    
    # Finding .smt2 files
    smt_files = [os.path.join(directory, f) for f in sorted(os.listdir(directory)) if f.endswith('.smt2')]

    # No. of .smt2 have to be at least 2
    if len(smt_files) < 2:
        print("Not enough SMT formulas to create pairs.")
        return

    # Randomly changing the order of the files in the directory
    random.shuffle(smt_files)

    # Ensure each formula exists in only one pair
    pairs = [(smt_files[i], smt_files[i + 1]) for i in range(0, len(smt_files) - 1, 2)]

    # If there is an odd number of files, we pair the last file with the first file
    if len(smt_files) % 2 != 0:
        pairs.append((smt_files[-1], smt_files[0]))

    valid_formula_counter = 0
    satisfiable_formula_counter = 0
    unsatisfiable_formula_counter = 0
    error_formula_counter = 0

    csv_file = "fused_results_sat.csv"    
    
    with open(csv_file, mode="w", newline="") as csvfile:
        csv_writer = csv.writer(csvfile)
        # Write header
        csv_writer.writerow(["Formula Pair", "Error", "Satisfiability", "Validity"])

        for file1, file2 in pairs:
            # Read in formulas from files
            with open(file1, "r") as f1, open(file2, "r") as f2:
                formula1 = f1.read()
                formula2 = f2.read()

            print(f"Processing pair:\nFormula 1 (from {file1}):\n")
            print(f"Formula 2 (from {file2}):\n")

            # Fuse formulas
            response = chain.invoke({"formula1": formula1, "formula2": formula2}, timeout=120)

            # Fusion result
            print(f"Fusion Result:\n{response.content}\n")

            # Validation result
            validation_result = validate_and_solve_smt(response.content)
           
            error = None
            satisfiability = None
            validity = None

            if validation_result.startswith("SMT formula is valid"):
                validity = "Valid"
                valid_formula_counter += 1
            if "Satisfiability result: sat" in validation_result:
                satisfiability = "SAT"
                satisfiable_formula_counter += 1
            elif "Satisfiability result: unsat" in validation_result:
                satisfiability = "UNSAT"
                unsatisfiable_formula_counter += 1
                # shutil.copy(file1, os.path.join(unsat_directory, os.path.basename(file1)))
                # shutil.copy(file2, os.path.join(unsat_directory, os.path.basename(file2)))
            if "Error" in validation_result or "error" in validation_result:
                error = validation_result
                error_formula_counter += 1
                # shutil.copy(file1, os.path.join(unsat_directory, os.path.basename(file1)))
                # shutil.copy(file2, os.path.join(unsat_directory, os.path.basename(file2)))

            # Write to CSV
            csv_writer.writerow([f"{file1} & {file2}", error, satisfiability, validity])
    
    # If there are files in the unsat_directory, shuffle and process them again
    # if os.listdir(unsat_directory):  # Check if the directory is not empty
    #     print(f"Reprocessing UNSAT/Error pairs in {unsat_directory}...")
    #     extract_and_fuse_smt_pairs(unsat_directory, chain)        
            
    print("\nValid Fused Formulas: " + f"{valid_formula_counter}\n")
    print("SAT Fused Formulas: " + f"{satisfiable_formula_counter}\n")
    print("UNSAT Fused Formulas: " + f"{unsatisfiable_formula_counter}\n")
    print("Fused Formulas with Errors: " + f"{error_formula_counter}\n")
    print(f"Results saved to {csv_file}")

fuse_formula_pairs("./seeds_BV_sat", get_new_chain())
# Out:
# SMT formula is valid.
# Satisfiability result: unsat
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_3347.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_446.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_10428 () (_ BitVec 8))
# (declare-fun T2_486 () (_ BitVec 16))
# (declare-fun T2_476 () (_ BitVec 16))
# (declare-fun T1_486 () (_ BitVec 8))
# (declare-fun T1_487 () (_ BitVec 8))
# (declare-fun T1_476 () (_ BitVec 8))
# (declare-fun T1_477 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 16))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 16))) (_ BitVec 16) (bvor ((_ zero_extend 8) x) y))
# (assert (let ((?v_0 ((_ sign_extend 8) T1_10428)))
#   (and true
#     (= ?v_0 (_ bv47 16))
#     (not (= T1_10428 (_ bv92 8)))
#     (not (= T1_10428 (_ bv0 8)))
#     (not (= ?v_0 (_ bv92 16)))
#     (not (= ?v_0 (_ bv37 16)))
#     (bvult ?v_0 (_ bv128 16))
#     (not (= ?v_0 (_ bv0 16)))
#     (= z (f T1_10428 T2_486)))))
# (assert (let ((?v_29 ((_ zero_extend 16) T2_486))
#               (?v_32 ((_ zero_extend 24) (_ bv3 8)))
#               (?v_3 ((_ zero_extend 16) T2_476)))
#   (let ((?v_30 (bvadd ?v_29 ?v_29)))
#     (let ((?v_31 (bvadd ?v_30 ?v_30))
#           (?v_28 (bvsle ?v_3 (_ bv1 32)))
#           (?v_12 (bvadd ?v_3 ?v_3))
#           (?v_27 (bvmul ?v_3 ((_ zero_extend 24) (_ bv112 8))))
#           (?v_9 (bvmul ?v_3 (_ bv18 32)))
#           (?v_26 (bvshl ?v_3 ((_ zero_extend 24) (_ bv5 8))))
#           (?v_25 (bvmul ?v_3 ((_ zero_extend 24) (_ bv92 8))))
#           (?v_24 (bvmul ?v_3 (_ bv2592 32)))
#           (?v_23 (bvshl ?v_3 ((_ zero_extend 24) (_ bv2 8))))
#           (?v_22 (bvmul ?v_3 (_ bv152 32))))
#       (let ((?v_13 (bvadd ?v_12 ?v_12))
#             (?v_21 (bvmul ?v_3 (_ bv1024 32)))
#             (?v_0 (bvmul ?v_3 (_ bv8 32))))
#         (let ((?v_1 (bvadd ?v_0 ?v_0)))
#           (let ((?v_2 (bvadd ?v_1 ?v_1))
#                 (?v_20 (bvadd ?v_13 (_ bv32 32)))
#                 (?v_19 (bvadd ?v_13 ?v_13))
#                 (?v_4 (bvmul ?v_3 (_ bv768 32))))
#             (let ((?v_5 (bvadd ?v_4 ?v_4)))
#               (let ((?v_18 (bvadd ?v_5 ?v_5))
#                     (?v_10 (bvadd ?v_9 ?v_9)))
#                 (let ((?v_17 (bvadd ?v_10 ?v_10))
#                       (?v_7 (bvmul ?v_3 (_ bv512 32))))
#                   (let ((?v_8 (bvadd ?v_7 ?v_7)))
#                     (let ((?v_16 (bvadd ?v_8 ?v_8))
#                           (?v_15 (bvadd ?v_2 ?v_2))
#                           (?v_14 (bvadd ?v_2 (_ bv64 32)))
#                           (?v_11 (bvadd ?v_18 (_ bv32 32))))
#                       (let ((?v_6 (bvadd ?v_15 (_ bv64 32))))
#                         (and true
#                           (= T2_476 (bvor (bvshl ((_ zero_extend 8) T1_477) (_ bv8 16)) ((_ zero_extend 8) T1_476)))
#                           (= z (f T1_10428 T2_486))
#                           (bvult (bvadd (bvshl (bvadd ?v_29 (_ bv4294967292 32)) ?v_32) (_ bv31 32)) (_ bv21 32))
#                           (bvult (bvsub (_ bv136 32) ?v_6) (_ bv63 32))
#                           (bvult (bvsub (_ bv3112 32) ?v_11) (_ bv63 32))
#                           (bvult (bvsub (_ bv104 32) ?v_14) (_ bv63 32))
#                           (bvult ?v_6 (_ bv2147483648 32))
#                           (not (= ?v_6 (_ bv0 32)))
#                           (bvule ?v_6 (_ bv2147483647 32))
#                           (bvult (bvsub (_ bv2056 32) ?v_16) (_ bv63 32))
#                           (bvult (bvsub (_ bv80 32) ?v_17) (_ bv63 32))
#                           (bvult ?v_11 (_ bv2147483648 32))
#                           (not (= ?v_11 (_ bv0 32)))
#                           (bvult (bvsub (_ bv16 32) ?v_19) (_ bv63 32))
#                           (bvult (bvsub (_ bv48 32) ?v_20) (_ bv63 32))
#                           (bvult ?v_14 (_ bv2147483648 32))
#                           (not (= ?v_14 (_ bv0 32)))
#                           (bvule ?v_14 (_ bv2147483647 32))
#                           (bvule (_ bv4 32) ?v_15)
#                           (bvult ?v_15 (_ bv256 32))
#                           (not (= ?v_15 (_ bv0 32)))
#                           (bvule ?v_15 (_ bv4294967231 32))
#                           (bvult ?v_16 (_ bv2147483648 32))
#                           (not (= ?v_16 (_ bv0 32)))
#                           (bvult ?v_17 (_ bv16384 32))
#                           (bvult ?v_17 (_ bv2147483648 32))
#                           (not (= ?v_17 (_ bv0 32)))
#                           (bvule (_ bv256 32) ?v_18)
#                           (not (= ?v_18 (_ bv0 32)))
#                           (bvule ?v_18 (_ bv4294967263 32))
#                           (bvule (_ bv4 32) ?v_19)
#                           (bvult ?v_19 (_ bv256 32))
#                           (not (= ?v_19 (_ bv0 32)))
#                           (not (= ?v_20 (_ bv0 32)))
#                           (bvule ?v_20 (_ bv2147483647 32))
#                           (bvult (bvsub (_ bv16 32) ?v_13) (_ bv63 32))
#                           (bvule (_ bv4 32) ?v_2)
#                           (bvult ?v_2 (_ bv256 32))
#                           (not (= ?v_2 (_ bv0 32)))
#                           (bvule ?v_2 (_ bv4294967231 32))
#                           (bvule (bvadd ?v_21 ?v_21) (_ bv2154 32))
#                           (bvult (bvsub (_ bv16 32) ?v_23) (_ bv63 32))
#                           (bvult (bvsub (_ bv40 32) ?v_26) (_ bv63 32))
#                           (bvult (bvsub (_ bv32 32) ?v_9) (_ bv63 32))
#                           (bvult (bvsub (_ bv120 32) ?v_27) (_ bv63 32))
#                           (bvult (bvsub (_ bv16 32) ?v_12) (_ bv63 32))
#                           (bvule ?v_13 (_ bv4294967263 32))
#                           (bvule (_ bv4 32) ?v_13)
#                           (bvult ?v_13 (_ bv256 32))
#                           (not (= ?v_13 (_ bv0 32)))
#                           (bvule ?v_13 (_ bv2147483647 32))
#                           (bvsle ((_ sign_extend 16) T2_476) (_ bv1 32))
#                           (= (bvsub ?v_3 (_ bv1 32)) (_ bv0 32))
#                           (bvult (bvsub (_ bv16 32) ?v_3) (_ bv63 32))
#                           (bvule (_ bv4 32) ?v_22)
#                           (bvult ?v_22 (_ bv256 32))
#                           (not (= ?v_22 (_ bv0 32)))
#                           (not (= ?v_23 (_ bv0 32)))
#                           (not (= ?v_24 (_ bv32 32)))
#                           (bvule (_ bv256 32) ?v_24)
#                           (not (= ?v_24 (_ bv0 32)))
#                           (bvule (_ bv4 32) ?v_25)
#                           (bvult ?v_25 (_ bv256 32))
#                           (not (= ?v_25 (_ bv0 32)))
#                           (bvule (_ bv4 32) ?v_26)
#                           (bvult ?v_26 (_ bv256 32))
#                           (not (= ?v_26 (_ bv0 32)))
#                           (not (= ?v_9 (_ bv0 32)))
#                           (bvult ?v_27 (_ bv2147483648 32))
#                           (not (= ?v_27 (_ bv0 32)))
#                           (not (= ?v_12 (_ bv0 32)))
#                           (= (bvmul ?v_3 (_ bv2 32)) (_ bv2 32))
#                           (bvsle T2_476 (_ bv1 16))
#                           (bvslt (_ bv0 16) T2_476)
#                           (bvult ?v_3 (_ bv4 32))
#                           (bvult ?v_3 (_ bv256 32))
#                           (not (= ?v_3 (_ bv0 32)))
#                           ?v_28
#                           (= T2_476 (_ bv1 16))
#                           ?v_28
#                           (bvslt (_ bv0 32) ?v_3)
#                           (not (= T2_476 (_ bv2 16)))
#                           (not (= ?v_3 (_ bv2 32)))
#                           (bvule T2_476 (_ bv2 16))
#                           (bvule ?v_3 (_ bv2 32))
#                           (bvult ?v_3 (_ bv9 32))
#                           (bvule T2_476 (_ bv32 16))
#                           (bvult (_ bv0 16) T2_476)
#                           (not (= T2_476 (_ bv0 16)))
#                           (bvult (_ bv1 32) (bvadd ?v_31 ?v_31))
#                           (bvule (bvadd ?v_3 (_ bv1 32)) (bvshl ?v_29 ?v_32))
#                           (bvult (_ bv0 32) ?v_29)
#                           (bvslt (_ bv0 32) ?v_29)
#                           (bvule ?v_29 (_ bv1048576 32))
#                           (bvult (_ bv0 16) T2_486)
#                           (not (= ?v_29 (_ bv0 32)))))))))))))))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_3248.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_4214.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_10491 () (_ BitVec 8))
# (declare-fun T2_10800 () (_ BitVec 16))
# (declare-fun T1_10800 () (_ BitVec 8))
# (declare-fun T1_10801 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 16))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 16))) (_ BitVec 16) (bvadd ((_ zero_extend 8) x) y))
# (assert (let ((?v_0 ((_ sign_extend 8) T1_10491))) (and true (= ?v_0 (_ bv46 16)) (not (= T1_10491 (_ bv0 8))) (bvult ?v_0 (_ bv256 16)) (not (= ?v_0 (_ bv0 16))))))
# (assert (let ((?v_0 (bvadd ((_ zero_extend 16) T2_10800) ((_ zero_extend 24) (_ bv1 8))))) (and true (= T2_10800 (bvor (bvshl ((_ zero_extend 8) T1_10801) (_ bv8 16)) ((_ zero_extend 8) T1_10800))) (bvslt (_ bv32768 32) ?v_0) (bvult (_ bv0 16) T2_10800) (bvslt (_ bv0 32) ?v_0) (bvsle (_ bv0 32) ?v_0) (not (= ?v_0 (_ bv0 32))) (bvule ?v_0 (_ bv2147483647 32)))))
# (assert (= z (f T1_10491 T2_10800)))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_5128.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bgpd_bgpd_vc75771.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# Benchmarks generated by the Calysto static checker.  Provided by Domagoj
# Babic.  See http://www.cs.ubc.ca/~babic/index_benchmarks.htm.  Translated using
# Spear Sf2Smt translator.
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T2_11155 () (_ BitVec 16))
# (declare-fun T1_11155 () (_ BitVec 8))
# (declare-fun T1_11156 () (_ BitVec 8))
# (declare-fun v125755292 () (_ BitVec 32))
# (declare-fun v152418180 () (_ BitVec 32))
# (declare-fun o132528424 () (_ BitVec 1))
# (declare-fun v121523112 () (_ BitVec 64))
# (declare-fun v125892028 () (_ BitVec 64))
# (declare-fun o132551304 () (_ BitVec 64))
# (declare-fun o135329240 () (_ BitVec 64))
# (declare-fun o129788248 () (_ BitVec 64))
# (declare-fun o125050112 () (_ BitVec 1))
# (declare-fun o113736064 () (_ BitVec 1))
# (declare-fun o126362052 () (_ BitVec 1))
# (declare-fun o126242516 () (_ BitVec 1))
# (declare-fun o133445212 () (_ BitVec 1))
# (declare-fun o126831404 () (_ BitVec 1))
# (declare-fun o115291336 () (_ BitVec 1))
# (declare-fun o126395976 () (_ BitVec 1))
# (declare-fun o136580064 () (_ BitVec 1))
# (declare-fun v125992288 () (_ BitVec 32))
# (declare-fun o111864348 () (_ BitVec 32))
# (declare-fun o109592516 () (_ BitVec 1))
# (declare-fun o121580388 () (_ BitVec 1))
# (declare-fun Fresh__0 () (_ BitVec 1))
# (declare-fun Fresh__1 () (_ BitVec 1))
# (declare-fun Fresh__2 () (_ BitVec 1))
# (declare-fun Fresh__3 () (_ BitVec 1))
# (declare-fun Fresh__4 () (_ BitVec 1))
# (declare-fun Fresh__5 () (_ BitVec 1))
# (declare-fun Fresh__6 () (_ BitVec 1))
# (declare-fun Fresh__7 () (_ BitVec 1))
# (declare-fun z () (_ BitVec 16))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 32))) (_ BitVec 16) (bvor ((_ zero_extend 8) x) ((_ extract 15 0) y)))
# (assert (and true (= T2_11155 (bvor (bvshl ((_ zero_extend 8) T1_11156) (_ bv8 16)) ((_ zero_extend 8) T1_11155))) (= T2_11155 (_ bv65535 16))))
# (assert (= (= Fresh__0 (_ bv1 1)) (bvslt v125755292 v152418180)))
# (assert (= o132528424 Fresh__0))
# (assert (= o132551304 (bvsdiv v121523112 v125892028)))
# (assert (= o135329240 (bvmul o132551304 ((_ extract 63 0) (_ bv5 64)))))
# (assert (= o129788248 (ite (= o132528424 (_ bv1 1)) o135329240 ((_ extract 63 0) (_ bv0 64)))))
# (assert (= (= Fresh__1 (_ bv1 1)) (bvsle ((_ extract 63 0) (_ bv86400 64)) o129788248)))
# (assert (= o125050112 Fresh__1))
# (assert (= (= Fresh__2 (_ bv1 1)) (distinct o129788248 ((_ extract 63 0) (_ bv0 64)))))
# (assert (= o113736064 Fresh__2))
# (assert (= (= Fresh__3 (_ bv1 1)) (bvsle v152418180 v125755292)))
# (assert (= o126362052 Fresh__3))
# (assert (= o126242516 (bvand o126362052 ((_ extract 0 0) (_ bv1 64)))))
# (assert (= o133445212 (ite (= o132528424 (_ bv1 1)) ((_ extract 0 0) (_ bv1 64)) o126242516)))
# (assert (= o126831404 (bvand o113736064 o133445212)))
# (assert (= o115291336 (bvand o125050112 o126831404)))
# (assert (= (= Fresh__4 (_ bv1 1)) (bvslt o129788248 ((_ extract 63 0) (_ bv604800 64)))))
# (assert (= o126395976 Fresh__4))
# (assert (= o136580064 (bvand o115291336 o126395976)))
# (assert (= o111864348 (ite (= o132528424 (_ bv1 1)) v125992288 ((_ extract 31 0) (_ bv0 64)))))
# (assert (= (= Fresh__5 (_ bv1 1)) (distinct o111864348 ((_ extract 31 0) (_ bv0 64)))))
# (assert (= o109592516 Fresh__5))
# (assert (= (= Fresh__6 (_ bv1 1)) (=> (= o136580064 (_ bv1 1)) (= o109592516 (_ bv1 1)))))
# (assert (= o121580388 Fresh__6))
# (assert (= (= Fresh__7 (_ bv1 1)) (= ((_ extract 0 0) (_ bv0 64)) o121580388)))
# (assert (= (_ bv1 1) Fresh__7))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_2659.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_3295.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_19414 () (_ BitVec 8))
# (declare-fun T1_19347 () (_ BitVec 8))
# (declare-fun T1_19281 () (_ BitVec 8))
# (declare-fun T1_19225 () (_ BitVec 8))
# (declare-fun T1_19221 () (_ BitVec 8))
# (declare-fun T2_18829 () (_ BitVec 16))
# (declare-fun T1_18820 () (_ BitVec 8))
# (declare-fun T1_19484 () (_ BitVec 8))
# (declare-fun T2_19223 () (_ BitVec 16))
# (declare-fun T4_18821 () (_ BitVec 32))
# (declare-fun T1_19223 () (_ BitVec 8))
# (declare-fun T1_19224 () (_ BitVec 8))
# (declare-fun T1_18829 () (_ BitVec 8))
# (declare-fun T1_18830 () (_ BitVec 8))
# (declare-fun T1_18821 () (_ BitVec 8))
# (declare-fun T1_18822 () (_ BitVec 8))
# (declare-fun T1_18823 () (_ BitVec 8))
# (declare-fun T1_18824 () (_ BitVec 8))
# (declare-fun T1_10438 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (let ((?v_9 ((_ zero_extend 24) T1_19414)) (?v_8 ((_ zero_extend 24) T1_19347)) (?v_0 ((_ zero_extend 24) (_ bv1 8))) (?v_7 ((_ zero_extend 24) T1_19281)) (?v_6 ((_ zero_extend 24) T1_19225)) (?v_4 ((_ zero_extend 24) T1_19221)) (?v_3 ((_ zero_extend 16) T2_18829)) (?v_2 (bvsub ((_ zero_extend 24) T1_18820) (_ bv8 32)))) (let ((?v_10 (bvadd (bvadd (bvadd (bvadd (bvadd (bvadd (bvadd (bvadd ?v_2 (_ bv4286534 32)) ?v_3) (_ bv7 32)) ?v_4) (_ bv3 32)) ?v_6) ?v_0) ?v_7))) (let ((?v_1 (bvsub (bvadd (bvadd ?v_10 ?v_0) ?v_8) (_ bv4286503 32)))) (let ((?v_13 (bvsub (bvadd (bvadd ?v_1 (_ bv4286504 32)) ?v_9) (_ bv1 32))) (?v_11 (bvsub ?v_10 (_ bv4286503 32)))) (let ((?v_12 (bvsub (bvadd (bvadd ?v_11 (_ bv4286504 32)) ?v_8) (_ bv1 32))) (?v_5 ((_ zero_extend 16) T2_19223))) (and true (= T4_18821 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_18824) (_ bv8 32)) ((_ zero_extend 24) T1_18823)) (_ bv8 32)) ((_ zero_extend 24) T1_18822)) (_ bv8 32)) ((_ zero_extend 24) T1_18821))) (= T2_18829 (bvor (bvshl ((_ zero_extend 8) T1_18830) (_ bv8 16)) ((_ zero_extend 8) T1_18829))) (= T2_19223 (bvor (bvshl ((_ zero_extend 8) T1_19224) (_ bv8 16)) ((_ zero_extend 8) T1_19223))) (bvule ?v_13 (bvadd ?v_1 (_ bv4286560 32))) (not (= (bvadd (bvadd ?v_2 (_ bv30 32)) (_ bv4286504 32)) (_ bv0 32))) (bvult (_ bv0 32) ?v_3) (not (= ?v_3 (_ bv0 32))) (= T4_18821 ?v_3) (= ?v_4 (_ bv1 32)) (not (= ?v_5 (_ bv0 32))) (= (bvadd (bvadd (bvadd (bvadd (bvadd ?v_5 (bvsub (_ bv4294967295 32) ?v_6)) (bvsub (_ bv4294967295 32) ?v_7)) (bvsub (_ bv4294967295 32) ?v_8)) (bvsub (_ bv4294967295 32) ?v_9)) (bvsub (_ bv4294967295 32) ((_ zero_extend 24) T1_19484))) (_ bv0 32)) (bvult (bvadd ?v_11 (_ bv4286560 32)) ?v_12) (bvult (bvadd ?v_11 (_ bv4286550 32)) ?v_12) (bvult (bvadd ?v_1 (_ bv4286554 32)) ?v_13))))))))
# (assert (let ((?v_1 ((_ sign_extend 8) T1_10438)) (?v_0 ((_ zero_extend 24) T1_10438))) (and true (not (= ?v_0 (_ bv93 32))) (bvult (_ bv25 32) (bvsub ?v_0 (_ bv97 32))) (not (= ?v_1 (_ bv47 16))) (not (= ?v_1 (_ bv92 16))) (not (= ?v_1 (_ bv37 16))) (bvult ?v_1 (_ bv128 16)) (not (= ?v_1 (_ bv0 16))) (not (= T1_10438 (_ bv92 8))) (not (= T1_10438 (_ bv0 8))))))
# (assert (= z (f T1_18820 T1_10438)))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_6890.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_7096.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_117258 () (_ BitVec 8))
# (declare-fun T1_2172 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (and (not (= T1_117258 (_ bv116 8))) (not (= ((_ zero_extend 24) T1_2172) (_ bv60 32))) (= z (f T1_117258 T1_2172))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_7545.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_426.smt2):
# Exception ignored in: <function Solver.__del__ at 0x11ecf7910>
# Traceback (most recent call last):
#   File "/Users/dara/.local/lib/python3.10/site-packages/z3/z3.py", line 6881, in __del__
#     Z3_solver_dec_ref(self.ctx.ref(), self.solver)
#   File "/Users/dara/.local/lib/python3.10/site-packages/z3/z3core.py", line 3881, in Z3_solver_dec_ref
#     _elems.Check(a0)
#   File "/Users/dara/.local/lib/python3.10/site-packages/z3/z3core.py", line 1459, in Check
#     raise self.Exception(self.get_error_message(ctx, err))
# z3.z3types.Z3Exception: b'(error "line 1 column 1: unexpected character")\n(error "line 1 column 2: unexpected character")\n(error "line 1 column 3: unexpected character")\n'
# Fusion Result:
# ```
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_1451 () (_ BitVec 8))
# (declare-fun T1_1452 () (_ BitVec 8))
# (declare-fun T1_1453 () (_ BitVec 8))
# (declare-fun T1_1454 () (_ BitVec 8))
# (declare-fun T1_1993 () (_ BitVec 8))
# (declare-fun T1_1994 () (_ BitVec 8))
# (declare-fun T4_11113 () (_ BitVec 32))
# (declare-fun T4_9717 () (_ BitVec 32))
# (declare-fun T1_11113 () (_ BitVec 8))
# (declare-fun T1_11114 () (_ BitVec 8))
# (declare-fun T1_11115 () (_ BitVec 8))
# (declare-fun T1_11116 () (_ BitVec 8))
# (declare-fun T1_9717 () (_ BitVec 8))
# (declare-fun T1_9718 () (_ BitVec 8))
# (declare-fun T1_9719 () (_ BitVec 8))
# (declare-fun T1_9720 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 32))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 32))) (_ BitVec 32) (bvor ((_ zero_extend 24) x) y))
# (assert (let ((?v_3 ((_ zero_extend 24) (_ bv1 8))) (?v_2 ((_ zero_extend 24) (_ bv2 8))) (?v_1 (bvsub ((_ zero_extend 24) T1_1451) (_ bv48 32)))) (let ((?v_4 (bvsub (bvadd ((_ zero_extend 24) T1_1452) (bvshl (bvadd ?v_1 (bvshl ?v_1 ?v_2)) ?v_3)) (_ bv48 32)))) (let ((?v_5 (bvsub (bvadd ((_ zero_extend 24) T1_1453) (bvshl (bvadd ?v_4 (bvshl ?v_4 ?v_2)) ?v_3)) (_ bv48 32)))) (let ((?v_6 (bvadd ((_ zero_extend 24) T1_1454) (bvshl (bvadd ?v_5 (bvshl ?v_5 ?v_2)) ?v_3))) (?v_0 (bvsub ((_ zero_extend 24) T1_1993) (_ bv48 32)))) (let ((?v_8 (bvadd (bvsub (bvadd ((_ zero_extend 24) T1_1994) (bvshl (bvadd ?v_0 (bvshl ?v_0 ?v_2)) ?v_3)) (_ bv48 32)) (bvadd ?v_6 (_ bv83 32)))) (?v_7 (bvsub ?v_6 (_ bv48 32)))) (and true (= ?v_8 (_ bv4294967295 32)) (not (= ?v_7 (_ bv4294967295 32))) (bvule (_ bv0 32) ?v_7) (bvule (_ bv0 32) ?v_8))))))))
# (assert (let ((?v_0 (bvsdiv (_ bv0 32) z))) (and true (= T4_9717 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_9720) (_ bv8 32)) ((_ zero_extend 24) T1_9719)) (_ bv8 32)) ((_ zero_extend 24) T1_9718)) (_ bv8 32)) ((_ zero_extend 24) T1_9717))) (= z (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_11116) (_ bv8 32)) ((_ zero_extend 24) T1_11115)) (_ bv8 32)) ((_ zero_extend 24) T1_11114)) (_ bv8 32)) ((_ zero_extend 24) T1_11113))) (bvslt (_ bv4294967295 32) z) (bvule (bvadd (bvsdiv (bvmul ?v_0 (_ bv33 32)) (_ bv100 32)) (_ bv33 32)) (_ bv100 32)) (bvule ?v_0 (_ bv100 32)) (bvule ?v_0 (_ bv0 32)) (not (= T4_9717 (_ bv4294967295 32))) (not (= (_ bv0 32) z)) (bvule (_ bv0 32) z) (bvult (_ bv0 32) z) (= T4_9717 z) (not (= z (_ bv0 32))))))
# (check-sat)
# (exit)
# ```
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_3256.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_1007.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_14168 () (_ BitVec 8))
# (declare-fun T1_14150 () (_ BitVec 8))
# (declare-fun T1_14146 () (_ BitVec 8))
# (declare-fun T2_13754 () (_ BitVec 16))
# (declare-fun T1_13745 () (_ BitVec 8))
# (declare-fun T2_14148 () (_ BitVec 16))
# (declare-fun T1_14229 () (_ BitVec 8))
# (declare-fun T1_14202 () (_ BitVec 8))
# (declare-fun T1_14185 () (_ BitVec 8))
# (declare-fun T4_13746 () (_ BitVec 32))
# (declare-fun T1_14148 () (_ BitVec 8))
# (declare-fun T1_14149 () (_ BitVec 8))
# (declare-fun T1_13754 () (_ BitVec 8))
# (declare-fun T1_13755 () (_ BitVec 8))
# (declare-fun T1_13746 () (_ BitVec 8))
# (declare-fun T1_13747 () (_ BitVec 8))
# (declare-fun T1_13748 () (_ BitVec 8))
# (declare-fun T1_13749 () (_ BitVec 8))
# (declare-fun T1_12899 () (_ BitVec 8))
# (declare-fun T2_12908 () (_ BitVec 16))
# (declare-fun T1_12908 () (_ BitVec 8))
# (declare-fun T1_12909 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (let ((?v_10 ((_ zero_extend 24) T1_14168)) (?v_6 ((_ zero_extend 24) T1_14150)) (?v_9 ((_ zero_extend 24) T1_14146)) (?v_2 ((_ zero_extend 16) T2_13754)) (?v_1 ((_ zero_extend 24) T1_13745))) (let ((?v_3 (bvsub ?v_1 (_ bv8 32)))) (let ((?v_4 (bvadd (bvadd (bvadd (bvadd ?v_3 (_ bv1593031 32)) ?v_2) (_ bv7 32)) ?v_9))) (let ((?v_13 (bvadd (bvadd ?v_4 (_ bv3 32)) ?v_6))) (let ((?v_0 (bvsub (bvadd (bvadd ?v_13 ((_ zero_extend 24) (_ bv1 8))) ?v_10) (_ bv1592999 32)))) (let ((?v_15 (bvadd ?v_0 (_ bv1593000 32))) (?v_5 (bvsub ?v_4 (_ bv1592997 32)))) (let ((?v_14 (bvadd ?v_5 (_ bv1593000 32))) (?v_12 ((_ zero_extend 16) T2_14148)) (?v_11 ((_ zero_extend 24) T1_14185))) (let ((?v_7 (bvsub (bvadd ?v_14 ?v_6) (_ bv1 32))) (?v_8 (bvadd ?v_5 (_ bv1593017 32)))) (and true (= T4_13746 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_13749) (_ bv8 32)) ((_ zero_extend 24) T1_13748)) (_ bv8 32)) ((_ zero_extend 24) T1_13747)) (_ bv8 32)) ((_ zero_extend 24) T1_13746))) (= T2_13754 (bvor (bvshl ((_ zero_extend 8) T1_13755) (_ bv8 16)) ((_ zero_extend 8) T1_13754))) (= T2_14148 (bvor (bvshl ((_ zero_extend 8) T1_14149) (_ bv8 16)) ((_ zero_extend 8) T1_14148))) (= (bvadd ?v_0 (_ bv1593016 32)) (bvsub (bvadd ?v_15 ?v_11) (_ bv1 32))) (bvule (bvadd (bvadd (bvadd (bvadd (bvadd ?v_1 (_ bv1 32)) (_ bv1593022 32)) ?v_2) (_ bv6 32)) (_ bv1 32)) (_ bv1593846 32)) (not (= (bvadd (bvadd ?v_3 (_ bv31 32)) (_ bv1593000 32)) (_ bv0 32))) (bvule (_ bv8 32) ?v_1) (not (= ?v_1 (_ bv1 32))) (bvule ?v_3 (_ bv0 32)) (bvult (_ bv0 32) ?v_2) (not (= ?v_2 (_ bv0 32))) (= T4_13746 ?v_2) (not (= ?v_8 ?v_7)) (bvule ?v_7 ?v_8) (bvult ?v_9 (_ bv8 32)) (not (= ?v_9 (_ bv0 32))) (= ?v_9 (_ bv1 32)) (= (bvadd (bvadd (bvadd (bvadd (bvadd ?v_12 (bvsub (_ bv4294967295 32) ?v_6)) (bvsub (_ bv4294967295 32) ?v_10)) (bvsub (_ bv4294967295 32) ?v_11)) (bvsub (_ bv4294967295 32) ((_ zero_extend 24) T1_14202))) (bvsub (_ bv4294967295 32) ((_ zero_extend 24) T1_14229))) (_ bv0 32)) (not (= ?v_12 (_ bv0 32))) (not (= (bvadd (bvsub ?v_13 (_ bv1592999 32)) (_ bv1593000 32)) (_ bv0 32))) (not (= ?v_14 (_ bv0 32))) (not (= ?v_15 (_ bv0 32)))))))))))))
# (assert (let ((?v_0 ((_ zero_extend 24) z))) (and true (= T2_12908 (bvor (bvshl ((_ zero_extend 8) T1_12909) (_ bv8 16)) ((_ zero_extend 8) T1_12908))) (bvult ?v_0 (_ bv8 32)) (bvule (bvadd (bvadd (bvadd (bvadd (bvadd ?v_0 (_ bv1 32)) (_ bv4278974 32)) ((_ zero_extend 16) T2_12908)) (_ bv6 32)) (_ bv1 32)) (_ bv4279798 32)) (not (= ?v_0 (_ bv1 32))))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_4646.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_1969.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_5018 () (_ BitVec 8))
# (declare-fun T2_11215 () (_ BitVec 16))
# (declare-fun T4_11207 () (_ BitVec 32))
# (declare-fun T1_11206 () (_ BitVec 8))
# (declare-fun T1_11607 () (_ BitVec 8))
# (declare-fun T1_11611 () (_ BitVec 8))
# (declare-fun T1_11670 () (_ BitVec 8))
# (declare-fun T2_11609 () (_ BitVec 16))
# (declare-fun T1_11790 () (_ BitVec 8))
# (declare-fun T1_11730 () (_ BitVec 8))
# (declare-fun T1_11609 () (_ BitVec 8))
# (declare-fun T1_11610 () (_ BitVec 8))
# (declare-fun T1_11215 () (_ BitVec 8))
# (declare-fun T1_11216 () (_ BitVec 8))
# (declare-fun T1_11207 () (_ BitVec 8))
# (declare-fun T1_11208 () (_ BitVec 8))
# (declare-fun T1_11209 () (_ BitVec 8))
# (declare-fun T1_11210 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 16))) (_ BitVec 8) x)
# (assert (and true (= T1_5018 (_ bv32 8)) (not (= T1_5018 (_ bv0 8)))))
# (assert (let ((?v_1 ((_ zero_extend 16) T2_11215)) (?v_12 ((_ zero_extend 24) T1_11206))) (let ((?v_13 (bvsub ?v_12 (_ bv8 32))) (?v_11 ((_ zero_extend 24) T1_11607))) (let ((?v_7 (bvadd (bvadd (bvadd (bvadd ?v_13 (_ bv4276870 32)) ?v_1) (_ bv7 32)) ?v_11))) (let ((?v_8 (bvsub ?v_7 (_ bv4276837 32)))) (let ((?v_10 (bvadd ?v_8 (_ bv4276840 32))) (?v_2 ((_ zero_extend 24) T1_11611))) (let ((?v_9 (bvsub (bvadd ?v_10 ?v_2) (_ bv1 32))) (?v_3 (bvsub (bvadd (bvadd ?v_7 (_ bv3 32)) ?v_2) (_ bv4276839 32)))) (let ((?v_6 (bvadd ?v_3 (_ bv4276840 32))) (?v_4 ((_ zero_extend 24) T1_11670))) (let ((?v_5 (bvsub (bvadd ?v_6 ?v_4) (_ bv1 32))) (?v_0 ((_ zero_extend 16) T2_11609))) (and true (= T4_11207 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_11210) (_ bv8 32)) ((_ zero_extend 24) T1_11209)) (_ bv8 32)) ((_ zero_extend 24) T1_11208)) (_ bv8 32)) ((_ zero_extend 24) T1_11207))) (= T2_11215 (bvor (bvshl ((_ zero_extend 8) T1_11216) (_ bv8 16)) ((_ zero_extend 8) T1_11215))) (= T2_11609 (bvor (bvshl ((_ zero_extend 8) T1_11610) (_ bv8 16)) ((_ zero_extend 8) T1_11609))) (= ?v_1 (_ bv0 32)) (= (bvadd (bvadd (bvadd (bvadd ?v_0 (bvsub (_ bv4294967295 32) ?v_2)) (bvsub (_ bv4294967295 32) ?v_4)) (bvsub (_ bv4294967295 32) ((_ zero_extend 24) T1_11730))) (bvsub (_ bv4294967295 32) ((_ zero_extend 24) T1_11790))) (_ bv0 32)) (not (= ?v_0 (_ bv0 32))) (= (bvadd ?v_3 (_ bv4276898 32)) ?v_5) (bvult (bvadd ?v_3 (_ bv4276876 32)) ?v_5) (bvult (bvadd ?v_3 (_ bv4276864 32)) ?v_5) (bvult (bvadd ?v_3 (_ bv4276846 32)) ?v_5) (not (= ?v_6 (_ bv0 32))) (bvult (bvadd ?v_8 (_ bv4276886 32)) ?v_9) (bvult (bvadd ?v_8 (_ bv4276856 32)) ?v_9) (not (= ?v_10 (_ bv0 32))) (bvult ?v_11 (_ bv8 32)) (not (= ?v_11 (_ bv0 32))) (= ?v_11 (_ bv1 32)) (bvule (_ bv8 32) ?v_12) (not (= ?v_12 (_ bv1 32))) (bvule (bvadd (bvadd (bvadd (bvadd (bvadd ?v_12 (_ bv1 32)) (_ bv4276861 32)) ?v_1) (_ bv6 32)) (_ bv1 32)) (_ bv4277686 32)) (bvule ?v_13 (_ bv0 32)) (= T4_11207 ?v_1)))))))))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_7149.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_4281.smt2):
#
# Fusion Result:
# (set-logic QF_BV)
# (declare-fun T1_123140 () (_ BitVec 8))
# (declare-fun T2_10782 () (_ BitVec 16))
# (declare-fun T1_10782 () (_ BitVec 8))
# (declare-fun T1_10783 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 16))) (_ BitVec 8) x)
# (assert (and (not (= T1_123140 (_ bv102 8))) (= z (f T1_123140 T2_10782))))
# (assert (let ((?v_0 ((_ zero_extend 16) T2_10782))) (and (= T2_10782 (bvor (bvshl ((_ zero_extend 8) T1_10783) (_ bv8 16)) ((_ zero_extend 8) T1_10782))) (not (= ?v_0 (_ bv8 32))) (not (= ?v_0 (_ bv0 32))) (= z T1_10782))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_1941.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_722.smt2):
#
# Fusion Result:
# (set-logic QF_BV)
# (declare-fun T2_673 () (_ BitVec 16))
# (declare-fun T2_733 () (_ BitVec 16))
# (declare-fun T1_733 () (_ BitVec 8))
# (declare-fun T1_734 () (_ BitVec 8))
# (declare-fun T1_673 () (_ BitVec 8))
# (declare-fun T1_674 () (_ BitVec 8))
# (declare-fun T2_7220 () (_ BitVec 16))
# (declare-fun T1_7220 () (_ BitVec 8))
# (declare-fun T1_7221 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 16))
# (define-fun f ((x (_ BitVec 16)) (y (_ BitVec 16))) (_ BitVec 16) (bvand x y))
# (assert (and (= z (f T2_673 T2_7220))
#              (= T2_673 (bvor (bvshl ((_ zero_extend 8) T1_674) (_ bv8 16)) ((_ zero_extend 8) T1_673)))
#              (= T2_733 (bvor (bvshl ((_ zero_extend 8) T1_734) (_ bv8 16)) ((_ zero_extend 8) T1_733)))
#              (not (= T2_673 (_ bv83 16)))
#              (not (= T2_733 (_ bv0 16)))
#              (= T2_673 T2_733)
#              (not (= T2_673 (_ bv0 16)))
#              (= T2_7220 (bvor (bvshl ((_ zero_extend 8) T1_7221) (_ bv8 16)) ((_ zero_extend 8) T1_7220)))
#              (= ((_ zero_extend 16) T2_7220) (_ bv0 32))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_835.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_7501.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_14873 () (_ BitVec 8))
# (declare-fun T1_2040 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (and (not (= (bvand (_ bv1 8) ((_ extract 7 0) (bvand (bvand ((_ zero_extend 24) T1_14873) (_ bv255 32)) (_ bv7 32)))) (_ bv0 8))) (not (= (_ bv99 8) T1_2040))))
# (assert (= z (f T1_14873 T1_2040)))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_7532.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_4569.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_2138 () (_ BitVec 8))
# (declare-fun T1_10620 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (and (not (= T1_2138 (_ bv116 8))) (= T1_10620 (_ bv0 8))))
# (assert (= z (f T1_2138 T1_10620)))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_1715.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_1720.smt2):
#
# Fusion Result:
# (declare-fun T1_1899 () (_ BitVec 8))
# (declare-fun T1_88 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (and (= ((_ zero_extend 24) (bvsub z T1_88)) (_ bv1 32)) (bvult (bvsub z T1_1899) (_ bv48 8))))
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_308.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_4531.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T2_21366 () (_ BitVec 16))
# (declare-fun T1_21357 () (_ BitVec 8))
# (declare-fun T1_21366 () (_ BitVec 8))
# (declare-fun T1_21367 () (_ BitVec 8))
# (declare-fun T1_5918 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (and true (= T2_21366 (bvor (bvshl ((_ zero_extend 8) T1_21367) (_ bv8 16)) ((_ zero_extend 8) T1_21366))) (bvsle (_ bv1040 32) (bvsub (bvadd (bvadd (bvsub ((_ zero_extend 24) z) (_ bv8 32)) (_ bv1582341 32)) ((_ zero_extend 16) T2_21366)) (_ bv1582137 32)))))
# (assert (and true (= (_ bv108 8) (bvsub z T1_5918))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_3547.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_7826.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T4_10796 () (_ BitVec 32))
# (declare-fun T4_5786 () (_ BitVec 32))
# (declare-fun T1_10796 () (_ BitVec 8))
# (declare-fun T1_10797 () (_ BitVec 8))
# (declare-fun T1_10798 () (_ BitVec 8))
# (declare-fun T1_10799 () (_ BitVec 8))
# (declare-fun T1_5786 () (_ BitVec 8))
# (declare-fun T1_5787 () (_ BitVec 8))
# (declare-fun T1_5788 () (_ BitVec 8))
# (declare-fun T1_5789 () (_ BitVec 8))
# (declare-fun T1_1327 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (and true
#   (= T4_5786 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_5789) (_ bv8 32)) ((_ zero_extend 24) T1_5788)) (_ bv8 32)) ((_ zero_extend 24) T1_5787)) (_ bv8 32)) ((_ zero_extend 24) T1_5786)))
#   (= T4_10796 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_10799) (_ bv8 32)) ((_ zero_extend 24) T1_10798)) (_ bv8 32)) ((_ zero_extend 24) T1_10797)) (_ bv8 32)) ((_ zero_extend 24) T1_10796)))
#   (bvslt (_ bv4294967295 32) T4_10796)
#   (not (= T4_5786 (_ bv4294967295 32)))
#   (not (= (_ bv0 32) T4_10796))
#   (bvule (_ bv0 32) T4_10796)
#   (= T4_5786 T4_10796)
#   (not (= T4_10796 (_ bv0 32)))
#   (not (= (bvsub z T1_1327) (_ bv110 8)))
# ))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_5232.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_7748.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_6 () (_ BitVec 8))
# (declare-fun T1_1479 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (let ((?v_0 ((_ zero_extend 24) T1_6))) (and true (= ?v_0 (_ bv10 32)) (not (= ?v_0 (_ bv13 32))))))
# (assert (and true (= T1_1479 (_ bv110 8))))
# (assert (= z (f T1_6 T1_1479)))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_6813.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_5487.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_114127 () (_ BitVec 8))
# (declare-fun T1_114128 () (_ BitVec 8))
# (declare-fun T1_114129 () (_ BitVec 8))
# (declare-fun T4_10661 () (_ BitVec 32))
# (declare-fun T4_2864 () (_ BitVec 32))
# (declare-fun T1_10661 () (_ BitVec 8))
# (declare-fun T1_10662 () (_ BitVec 8))
# (declare-fun T1_10663 () (_ BitVec 8))
# (declare-fun T1_10664 () (_ BitVec 8))
# (declare-fun T1_2864 () (_ BitVec 8))
# (declare-fun T1_2865 () (_ BitVec 8))
# (declare-fun T1_2866 () (_ BitVec 8))
# (declare-fun T1_2867 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 32))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 32))) (_ BitVec 32) (bvadd ((_ zero_extend 24) x) y))
# (assert (let ((?v_3 ((_ zero_extend 24) (_ bv1 8))) (?v_2 ((_ zero_extend 24) (_ bv2 8))) (?v_0 (bvsub ((_ zero_extend 24) T1_114127) (_ bv48 32)))) (let ((?v_1 (bvsub (bvadd ((_ zero_extend 24) T1_114128) (bvshl (bvadd ?v_0 (bvshl ?v_0 ?v_2)) ?v_3)) (_ bv48 32)))) (let ((?v_4 (bvadd ((_ zero_extend 24) T1_114129) (bvshl (bvadd ?v_1 (bvshl ?v_1 ?v_2)) ?v_3)))) (and true (bvslt (bvsub ?v_4 (_ bv148 32)) (_ bv0 32)) (bvsle (_ bv0 32) (bvsub ?v_4 (_ bv49 32))) (bvslt (_ bv0 32) (bvsub ?v_4 (_ bv48 32))))))))
# (assert (let ((?v_9 (bvsdiv (_ bv0 32) z)) (?v_8 (bvsub z (_ bv2048 32))) (?v_7 (bvsub z (_ bv4095 32))) (?v_6 (bvsub z (_ bv6143 32))) (?v_5 (bvadd z (_ bv143502555 32))) (?v_4 (bvsub (_ bv0 32) ((_ zero_extend 24) (ite (bvult z (_ bv0 32)) (_ bv1 8) (_ bv0 8)))))) (let ((?v_3 (bvsub (_ bv0 32) ((_ zero_extend 24) (ite (bvult ?v_8 (_ bv0 32)) (_ bv1 8) (_ bv0 8))))) (?v_2 (bvsub (_ bv0 32) ((_ zero_extend 24) (ite (bvult ?v_7 (_ bv0 32)) (_ bv1 8) (_ bv0 8))))) (?v_1 (bvsub (_ bv0 32) ((_ zero_extend 24) (ite (bvult ?v_6 (_ bv0 32)) (_ bv1 8) (_ bv0 8)))))) (let ((?v_0 (bvule ?v_1 (_ bv0 32)))) (and true (= T4_2864 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_2867) (_ bv8 32)) ((_ zero_extend 24) T1_2866)) (_ bv8 32)) ((_ zero_extend 24) T1_2865)) (_ bv8 32)) ((_ zero_extend 24) T1_2864))) (= z (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_10664) (_ bv8 32)) ((_ zero_extend 24) T1_10663)) (_ bv8 32)) ((_ zero_extend 24) T1_10662)) (_ bv8 32)) ((_ zero_extend 24) T1_10661))) (bvslt (bvsub z (_ bv6994 32)) (_ bv0 32)) ?v_0 ?v_0 (bvule (_ bv0 32) ?v_1) (bvule ?v_2 (_ bv0 32)) (bvule (_ bv0 32) ?v_2) (bvule ?v_3 (_ bv0 32)) (bvule (_ bv0 32) ?v_3) (bvule ?v_4 (_ bv0 32)) (bvule (_ bv0 32) ?v_4) (bvule ?v_5 (_ bv143509549 32)) (bvult (_ bv143509540 32) ?v_5) (bvule (_ bv258 32) (bvsub z (_ bv6144 32))) (not (= ?v_6 (_ bv0 32))) (bvult (_ bv0 32) ?v_6) (bvule ?v_6 (_ bv2044 32)) (bvult (_ bv2048 32) ?v_7) (bvult (_ bv2047 32) ?v_8) (bvule ?v_9 (_ bv100 32)) (bvule ?v_9 (_ bv0 32)) (not (= T4_2864 (_ bv4294967295 32))) (bvult (_ bv6143 32) z) (not (= (_ bv6143 32) z)) (bvule (_ bv6143 32) z) (not (= (_ bv4095 32) z)) (not (= (_ bv2048 32) z)) (bvult (_ bv2048 32) z) (not (= (_ bv0 32) z)) (bvult (_ bv0 32) z) (= T4_2864 z) (not (= z (_ bv0 32))))))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_3232.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_3329.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_10495 () (_ BitVec 8))
# (declare-fun T1_99269 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (let ((?v_0 ((_ sign_extend 8) T1_10495)))
#   (and true
#     (not (= ?v_0 (_ bv46 16)))
#     (not (= T1_10495 (_ bv0 8)))
#     (bvult ?v_0 (_ bv256 16))
#     (not (= ?v_0 (_ bv0 16)))
#     (not (= (bvand (bvsub z T1_99269) (_ bv15 8)) (_ bv8 8)))
#     (not (= ((_ zero_extend 24) (bvsub z T1_99269)) (_ bv4294967295 32)))
#   )
# ))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_3345.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_809.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_10430 () (_ BitVec 8))
# (declare-fun T1_14874 () (_ BitVec 8))
# (declare-fun T1_14883 () (_ BitVec 8))
# (declare-fun T1_14916 () (_ BitVec 8))
# (declare-fun T1_14924 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (let ((?v_0 ((_ sign_extend 8) T1_10430)))
#   (and true
#     (= ?v_0 (_ bv47 16))
#     (not (= T1_10430 (_ bv92 8)))
#     (not (= T1_10430 (_ bv0 8)))
#     (not (= ?v_0 (_ bv92 16)))
#     (not (= ?v_0 (_ bv37 16)))
#     (bvult ?v_0 (_ bv128 16))
#     (not (= ?v_0 (_ bv0 16)))
#     (= z (f T1_10430 T1_14874)))))
# (assert (let ((?v_5 (bvand (bvand ((_ zero_extend 24) T1_14874) (_ bv255 32)) (_ bv31 32))))
#   (let ((?v_0 (bvadd ?v_5 ((_ zero_extend 24) (_ bv1 8)))))
#     (let ((?v_4 (bvadd ?v_0 (_ bv273 32)))
#           (?v_3 (bvand (bvor (bvshl (bvand ((_ zero_extend 24) T1_14883) (_ bv255 32)) ((_ zero_extend 24) (_ bv5 8))) (_ bv10 32)) (_ bv127 32)))
#           (?v_2 (bvand (bvor (bvshl (bvand ((_ zero_extend 24) T1_14916) (_ bv255 32)) ((_ zero_extend 24) (_ bv4 8))) (_ bv6 32)) (_ bv127 32)))
#           (?v_1 (bvand (bvshl (bvand ((_ zero_extend 24) T1_14924) (_ bv255 32)) ((_ zero_extend 24) (_ bv2 8))) (_ bv7 32))))
#       (and true
#         (bvslt (_ bv22 32) ?v_0)
#         (not (= ?v_2 (_ bv4294967295 32)))
#         (not (= ?v_1 (_ bv4294967295 32)))
#         (not (= ?v_3 (_ bv4294967295 32)))
#         (bvsle ?v_4 (bvadd (bvadd (bvadd ?v_1 (_ bv3 32)) (bvadd (bvadd (bvadd ?v_2 (_ bv11 32)) (bvadd ?v_3 (_ bv117 32))) (_ bv17 32))) (_ bv19 32)))
#         (bvsle (bvadd ?v_3 (_ bv42 32)) ?v_4)
#         (bvslt (_ bv0 32) ?v_4)
#         (not (= ?v_5 (_ bv4294967295 32)))
#         (bvslt (_ bv21 32) ?v_0)
#         (bvslt (_ bv0 32) ?v_0)
#         (bvsle ?v_0 (_ bv30 32))
#         (= z (f T1_10430 T1_14874)))))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_3936.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_609.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_111774 () (_ BitVec 8))
# (declare-fun T4_10989 () (_ BitVec 32))
# (declare-fun T4_7214 () (_ BitVec 32))
# (declare-fun T1_10989 () (_ BitVec 8))
# (declare-fun T1_10990 () (_ BitVec 8))
# (declare-fun T1_10991 () (_ BitVec 8))
# (declare-fun T1_10992 () (_ BitVec 8))
# (declare-fun T1_7214 () (_ BitVec 8))
# (declare-fun T1_7215 () (_ BitVec 8))
# (declare-fun T1_7216 () (_ BitVec 8))
# (declare-fun T1_7217 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 32))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 32))) (_ BitVec 32) (bvadd ((_ zero_extend 24) x) y))
# (assert (and true (= (bvsub ((_ sign_extend 24) T1_111774) (_ bv51 32)) (_ bv0 32))))
# (assert (let ((?v_4 (bvadd T4_10989 (_ bv143554326 32))) (?v_3 (bvult (_ bv0 32) T4_10989)) (?v_2 (bvsdiv (_ bv0 32) T4_10989)) (?v_1 (bvsub (_ bv0 32) ((_ zero_extend 24) (ite (bvult T4_10989 (_ bv0 32)) (_ bv1 8) (_ bv0 8)))))) (let ((?v_0 (bvule ?v_1 (_ bv0 32)))) (and true (= T4_7214 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_7217) (_ bv8 32)) ((_ zero_extend 24) T1_7216)) (_ bv8 32)) ((_ zero_extend 24) T1_7215)) (_ bv8 32)) ((_ zero_extend 24) T1_7214))) (= T4_10989 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_10992) (_ bv8 32)) ((_ zero_extend 24) T1_10991)) (_ bv8 32)) ((_ zero_extend 24) T1_10990)) (_ bv8 32)) ((_ zero_extend 24) T1_10989))) (bvult (_ bv143554982 32) ?v_4) (bvule (bvsdiv (bvmul ?v_2 (_ bv33 32)) (_ bv100 32)) (_ bv100 32)) ?v_0 ?v_0 (bvule (_ bv0 32) ?v_1) (bvule ?v_2 (_ bv100 32)) (bvule ?v_2 (_ bv0 32)) (not (= T4_7214 (_ bv4294967295 32))) (bvule (_ bv258 32) T4_10989) ?v_3 (bvule T4_10989 (_ bv2048 32)) (not (= (_ bv0 32) T4_10989)) (bvule (_ bv0 32) T4_10989) ?v_3 (= T4_7214 T4_10989) (not (= T4_10989 (_ bv0 32))) (bvult (_ bv143554979 32) ?v_4)))))
# (assert (= z (f T1_111774 T4_10989)))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_2589.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_7844.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_9920 () (_ BitVec 8))
# (declare-fun T1_9916 () (_ BitVec 8))
# (declare-fun T2_9524 () (_ BitVec 16))
# (declare-fun T1_9515 () (_ BitVec 8))
# (declare-fun T2_9918 () (_ BitVec 16))
# (declare-fun T4_9516 () (_ BitVec 32))
# (declare-fun T1_9943 () (_ BitVec 8))
# (declare-fun T1_9975 () (_ BitVec 8))
# (declare-fun T1_10036 () (_ BitVec 8))
# (declare-fun T1_10007 () (_ BitVec 8))
# (declare-fun T1_9918 () (_ BitVec 8))
# (declare-fun T1_9919 () (_ BitVec 8))
# (declare-fun T1_9524 () (_ BitVec 8))
# (declare-fun T1_9525 () (_ BitVec 8))
# (declare-fun T1_9516 () (_ BitVec 8))
# (declare-fun T1_9517 () (_ BitVec 8))
# (declare-fun T1_9518 () (_ BitVec 8))
# (declare-fun T1_9519 () (_ BitVec 8))
# (declare-fun T1_1147 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvxor x y))
# ...
# (declare-fun T1_3146 () (_ BitVec 8))
# (declare-fun T2_2754 () (_ BitVec 16))
# (declare-fun T1_2745 () (_ BitVec 8))
# (declare-fun T1_3343 () (_ BitVec 8))
# (declare-fun T1_3344 () (_ BitVec 8))
# (declare-fun T1_3155 () (_ BitVec 8))
# (declare-fun T1_3156 () (_ BitVec 8))
# (declare-fun T1_2754 () (_ BitVec 8))
# (declare-fun T1_2755 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (and true (bvslt (bvsub ((_ sign_extend 24) z) (_ bv72 32)) (_ bv0 32))))
# (assert (let ((?v_14 ((_ zero_extend 24) T1_3358)) (?v_10 ((_ zero_extend 24) T1_3345)) (?v_11 ((_ zero_extend 16) T2_3343))) (let ((?v_15 (bvadd ?v_11 (bvsub (_ bv4294967295 32) ?v_10)))) (let ((?v_17 (bvadd ?v_15 (bvsub (_ bv4294967295 32) ?v_14))) (?v_16 ((_ zero_extend 24) T1_3371)) (?v_7 ((_ zero_extend 24) T1_3341)) (?v_3 ((_ zero_extend 24) T1_3146)) (?v_1 ((_ zero_extend 24) T1_2745))) (let ((?v_0 (bvadd ?v_1 (_ bv1 32)))) (let ((?v_2 (bvadd (bvadd ?v_0 (_ bv1582332 32)) ((_ zero_extend 16) T2_2754)))) (let ((?v_4 (bvadd ?v_2 (_ bv6 32)))) (let ((?v_6 (bvadd (bvadd ?v_4 (bvadd ?v_3 (_ bv1 32))) (_ bv2 32)))) (let ((?v_5 (bvadd ?v_6 ((_ zero_extend 16) T2_3155)))) (let ((?v_8 (bvadd ?v_5 (_ bv6 32)))) (let ((?v_9 (bvadd ?v_8 (bvadd ?v_7 (_ bv1 32))))) (let ((?v_13 (bvadd ?v_9 (_ bv2 32)))) (let ((?v_12 (bvadd ?v_13 ?v_10))) (let ((?v_18 (bvadd (bvadd ?v_12 (_ bv1 32)) ?v_14))) (and true (= T2_2754 (bvor (bvshl ((_ zero_extend 8) T1_2755) (_ bv8 16)) ((_ zero_extend 8) T1_2754))) (= T2_3155 (bvor (bvshl ((_ zero_extend 8) T1_3156) (_ bv8 16)) ((_ zero_extend 8) T1_3155))) (= T2_3343 (bvor (bvshl ((_ zero_extend 8) T1_3344) (_ bv8 16)) ((_ zero_extend 8) T1_3343))) (bvult (_ bv1583158 32) (bvadd (bvadd (bvadd ?v_18 (_ bv1 32)) ?v_16) (_ bv2 32))) (bvule (bvadd (bvadd ?v_0 (_ bv1582330 32)) (_ bv2 32)) (_ bv1583158 32)) (not (= ?v_1 (_ bv1 32))) (bvule (bvsub ?v_2 (_ bv1582312 32)) (_ bv846 32)) (not (= ?v_3 (_ bv1 32))) (bvule (bvadd ?v_4 (_ bv1 32)) (_ bv1583158 32)) (bvule (bvsub ?v_5 (_ bv1582312 32)) (_ bv846 32)) (bvule ?v_6 (_ bv1583158 32)) (not (= ?v_7 (_ bv0 32))) (= ?v_7 (_ bv1 32)) (bvule (bvadd ?v_8 (_ bv1 32)) (_ bv1583158 32)) (bvule (bvadd ?v_9 (_ bv3 32)) (_ bv1583158 32)) (bvule (bvadd ?v_10 (_ bv1 32)) ?v_11) (not (= ?v_11 (_ bv0 32))) (bvule (bvadd ?v_12 (_ bv2 32)) (_ bv1583158 32)) (bvule ?v_13 (_ bv1583158 32)) (not (= ?v_15 (_ bv0 32))) (bvule (bvadd ?v_14 (_ bv1 32)) ?v_15) (not (= (bvadd ?v_17 (bvsub (_ bv4294967295 32) ?v_16)) (_ bv0 32))) (not (= ?v_17 (_ bv0 32))) (bvule (bvadd ?v_18 (_ bv2 32)) (_ bv1583158 32)) (bvule (bvadd ?v_16 (_ bv1 32)) ?v_17))))))))))))))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_8263.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_3062.smt2):
#
# Fusion Result:
# (set-logic QF_BV)
# (declare-fun T1_141 () (_ BitVec 8))
# (declare-fun T1_10560 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (let ((?v_0 ((_ zero_extend 24) T1_141))) (and true (= ?v_0 (_ bv46 32)) (bvule (bvsub ?v_0 (_ bv40 32)) (_ bv85 32)) (not (= ?v_0 (_ bv45 32))) (not (= ?v_0 (_ bv37 32))) (not (= ?v_0 (_ bv4294967295 32))))))
# (assert (let ((?v_0 ((_ sign_extend 8) T1_10560))) (and true (= ?v_0 (_ bv0 16)) (not (= ?v_0 (_ bv47 16))))))
# (assert (= z (f T1_141 T1_10560)))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_64.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_2880.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_30956 () (_ BitVec 8))
# (declare-fun T1_30953 () (_ BitVec 8))
# (declare-fun T1_30954 () (_ BitVec 8))
# (declare-fun T1_30955 () (_ BitVec 8))
# (declare-fun T2_5294 () (_ BitVec 16))
# (declare-fun T4_5286 () (_ BitVec 32))
# (declare-fun T1_5285 () (_ BitVec 8))
# (declare-fun T1_5686 () (_ BitVec 8))
# (declare-fun T2_5688 () (_ BitVec 16))
# (declare-fun T1_5690 () (_ BitVec 8))
# (declare-fun T1_5706 () (_ BitVec 8))
# (declare-fun T1_5731 () (_ BitVec 8))
# (declare-fun T1_5750 () (_ BitVec 8))
# (declare-fun T1_5763 () (_ BitVec 8))
# (declare-fun T1_5688 () (_ BitVec 8))
# (declare-fun T1_5689 () (_ BitVec 8))
# (declare-fun T1_5294 () (_ BitVec 8))
# (declare-fun T1_5295 () (_ BitVec 8))
# (declare-fun T1_5286 () (_ BitVec 8))
# (declare-fun T1_5287 () (_ BitVec 8))
# (declare-fun T1_5288 () (_ BitVec 8))
# (declare-fun T1_5289 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (let ((?v_10 ((_ zero_extend 8) T1_30956)) (?v_5 ((_ zero_extend 24) (_ bv1 8))) (?v_1 (bvadd ((_ zero_extend 24) T1_30953) (_ bv4294967248 32))) (?v_2 ((_ zero_extend 16) (_ bv9 16)))) (let ((?v_3 (bvadd (bvsub (_ bv0 32) ((_ zero_extend 24) (ite (bvult ?v_2 (bvadd ((_ zero_extend 24) ((_ extract 7 0) ?v_1)) (bvshl ((_ zero_extend 24) ((_ extract 15 8) ?v_1)) (_ bv8 32)))) (_ bv1 8) (_ bv0 8)))) ?v_5))) (let ((?v_4 (bvadd (bvadd (bvadd ((_ zero_extend 24) T1_30954) (bvshl ((_ zero_extend 24) ((_ extract 23 16) ?v_3)) (_ bv16 32))) (bvshl ((_ zero_extend 24) ((_ extract 31 24) ?v_3)) (_ bv24 32))) (_ bv4294967248 32)))) (let ((?v_6 (bvadd (bvsub (_ bv0 32) ((_ zero_extend 24) (ite (bvult ?v_2 (bvadd ((_ zero_extend 24) ((_ extract 7 0) ?v_4)) (bvshl ((_ zero_extend 24) ((_ extract 15 8) ?v_4)) (_ bv8 32)))) (_ bv1 8) (_ bv0 8)))) ?v_5))) (let ((?v_7 (bvadd (bvadd (bvadd ((_ zero_extend 24) T1_30955) (bvshl ((_ zero_extend 24) ((_ extract 23 16) ?v_6)) (_ bv16 32))) (bvshl ((_ zero_extend 24) ((_ extract 31 24) ?v_6)) (_ bv24 32))) (_ bv4294967248 32)))) (let ((?v_8 (bvadd (bvsub (_ bv0 32) ((_ zero_extend 24) (ite (bvult ?v_2 (bvadd ((_ zero_extend 24) ((_ extract 7 0) ?v_7)) (bvshl ((_ zero_extend 24) ((_ extract 15 8) ?v_7)) (_ bv8 32)))) (_ bv1 8) (_ bv0 8)))) ?v_5))) (let ((?v_9 (bvadd (bvadd (bvadd ((_ zero_extend 24) T1_30956) (bvshl ((_ zero_extend 24) ((_ extract 23 16) ?v_8)) (_ bv16 32))) (bvshl ((_ zero_extend 24) ((_ extract 31 24) ?v_8)) (_ bv24 32))) (_ bv4294967248 32))) (?v_0 ((_ zero_extend 8) T1_30953))) (and true (= (_ bv101 16) ?v_10) (not (= (_ bv43 16) ?v_0)) (not (= (_ bv45 16) ?v_0)) (not (= ((_ extract 7 0) ?v_3) (_ bv0 8))) (not (= ((_ extract 7 0) ?v_6) (_ bv0 8))) (= ((_ extract 7 0) (bvadd (bvsub (_ bv0 32) ((_ zero_extend 24) (ite (bvult ?v_2 (bvadd ((_ zero_extend 24) ((_ extract 7 0) ?v_9)) (bvshl ((_ zero_extend 24) ((_ extract 15 8) ?v_9)) (_ bv8 32)))) (_ bv1 8) (_ bv0 8)))) ?v_5)) (_ bv0 8)) (not (= ((_ extract 7 0) ?v_8) (_ bv0 8))) (not (= (_ bv46 16) ?v_10)))))))))))
# (assert (let ((?v_6 ((_ zero_extend 16) T2_5294)) (?v_10 ((_ zero_extend 24) T1_5285))) (let ((?v_18 (bvadd ?v_10 (_ bv1 32)))) (let ((?v_23 (bvadd (bvadd ?v_18 (_ bv4266174 32)) ?v_6)) (?v_21 (bvsub ?v_10 (_ bv8 32)))) (let ((?v_22 (bvadd (bvadd ?v_21 (_ bv4266183 32)) ?v_6)) (?v_20 (bvadd ?v_23 (_ bv6 32))) (?v_11 ((_ zero_extend 24) T1_5686))) (let ((?v_19 (bvadd (bvadd ?v_20 (bvadd ?v_11 (_ bv1 32))) (_ bv2 32))) (?v_7 ((_ zero_extend 16) T2_5688)) (?v_14 ((_ zero_extend 24) T1_5690)) (?v_12 (bvadd (bvadd ?v_22 (_ bv7 32)) ?v_11))) (let ((?v_13 (bvadd (bvadd ?v_12 (_ bv4266149 32)) ?v_11))) (let ((?v_17 (bvadd ?v_13 (_ bv4266152 32)))) (let ((?v_15 (bvsub (bvadd ?v_17 ?v_14) (_ bv1 32))) (?v_16 (bvadd ?v_13 (_ bv4266166 32))) (?v_9 (bvadd ?v_7 (bvsub (_ bv4294967295 32) ?v_14))) (?v_8 ((_ zero_extend 24) T1_5706))) (let ((?v_5 (bvadd ?v_9 (bvsub (_ bv4294967295 32) ?v_8))) (?v_4 ((_ zero_extend 24) T1_5731))) (let ((?v_3 (bvadd ?v_5 (bvsub (_ bv4294967295 32) ?v_4))) (?v_2 ((_ zero_extend 24) T1_5750))) (let ((?v_1 (bvadd ?v_3 (bvsub (_ bv4294967295 32) ?v_2))) (?v_0 ((_ zero_extend 24) T1_5763))) (and true (= T4_5286 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_5289) (_ bv8 32)) ((_ zero_extend 24) T1_5288)) (_ bv8 32)) ((_ zero_extend 24) T1_5287)) (_ bv8 32)) ((_ zero_extend 24) T1_5286))) (= T2_5294 (bvor (bvshl ((_ zero_extend 8) T1_5295) (_ bv8 16)) ((_ zero_extend 8) T1_5294))) (= T2_5688 (bvor (bvshl ((_ zero_extend 8) T1_5689) (_ bv8 16)) ((_ zero_extend 8) T1_5688))) (= ?v_6 (_ bv0 32)) (= (bvadd ?v_1 (bvsub (_ bv4294967295 32) ?v_0)) (_ bv0 32)) (bvule (bvadd ?v_0 (_ bv1 32)) ?v_1) (not (= ?v_1 (_ bv0 32))) (bvule (bvadd ?v_2 (_ bv1 32)) ?v_3) (not (= ?v_3 (_ bv0 32))) (bvule (bvadd ?v_4 (_ bv1 32)) ?v_5) (not (= ?v_5 (_ bv0 32))) (bvule (bvsub (bvadd (bvadd ?v_12 (_ bv2 32)) ?v_7) (_ bv4266152 32)) (_ bv846 32)) (bvule (bvadd ?v_8 (_ bv1 32)) ?v_9) (not (= ?v_9 (_ bv0 32))) (bvule (bvsub (bvadd ?v_19 ?v_7) (_ bv4266152 32)) (_ bv846 32)) (not (= (bvadd ?v_13 (_ bv4266167 32)) ?v_15)) (= ?v_16 ?v_15) (bvule ?v_15 ?v_16) (not (= ?v_17 (_ bv0 32))) (bvule (bvadd ?v_14 (_ bv1 32)) ?v_7) (not (= ?v_7 (_ bv0 32))) (bvule (bvadd (bvadd ?v_18 (_ bv4266172 32)) (_ bv2 32)) (_ bv4266998 32)) (bvule ?v_19 (_ bv4266998 32)) (bvult ?v_11 (_ bv8 32)) (not (= ?v_11 (_ bv0 32))) (= ?v_11 (_ bv1 32)) (bvule (_ bv8 32) ?v_10) (not (= ?v_10 (_ bv1 32))) (bvule (bvadd ?v_20 (_ bv1 32)) (_ bv4266998 32)) (bvule ?v_21 (_ bv0 32)) (bvule (bvsub ?v_22 (_ bv4266152 32)) (_ bv846 32)) (bvule (bvsub ?v_23 (_ bv4266152 32)) (_ bv846 32)) (= T4_5286 ?v_6))))))))))))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_5196.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_7916.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_742 () (_ BitVec 8))
# (declare-fun T1_547 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (and (not (= ((_ zero_extend 24) T1_742) (_ bv10 32))) (not (= T1_547 (_ bv110 8))) (= z (f T1_742 T1_547))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_4347.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_424.smt2):
#
# Fusion Result:
# (set-info :smt-lib-version 2.6)
# (set-logic QF_BV)
# (set-info :source |
#  Patrice Godefroid, SAGE (systematic dynamic test generation)
#  For more information: http://research.microsoft.com/en-us/um/people/pg/public_psfiles/ndss2008.pdf
# |)
# (set-info :category "industrial")
# (set-info :status sat)
# (declare-fun T1_111979 () (_ BitVec 8))
# (declare-fun T4_11113 () (_ BitVec 32))
# (declare-fun T4_9717 () (_ BitVec 32))
# (declare-fun T1_11113 () (_ BitVec 8))
# (declare-fun T1_11114 () (_ BitVec 8))
# (declare-fun T1_11115 () (_ BitVec 8))
# (declare-fun T1_11116 () (_ BitVec 8))
# (declare-fun T1_9717 () (_ BitVec 8))
# (declare-fun T1_9718 () (_ BitVec 8))
# (declare-fun T1_9719 () (_ BitVec 8))
# (declare-fun T1_9720 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 32))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 32))) (_ BitVec 32) (bvadd ((_ zero_extend 24) x) y))
# (assert (let ((?v_0 (bvand (bvand ((_ zero_extend 24) T1_111979) (_ bv255 32)) (_ bv31 32))))
#   (and true
#     (bvslt (_ bv30 32) (bvadd ?v_0 ((_ zero_extend 24) (_ bv1 8))))
#     (not (= ?v_0 (_ bv4294967295 32)))
#     (= z (f T1_111979 T4_11113)))))
# (assert (let ((?v_0 (bvsdiv (_ bv0 32) T4_11113)))
#   (and true
#     (= T4_9717 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_9720) (_ bv8 32)) ((_ zero_extend 24) T1_9719)) (_ bv8 32)) ((_ zero_extend 24) T1_9718)) (_ bv8 32)) ((_ zero_extend 24) T1_9717)))
#     (= T4_11113 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_11116) (_ bv8 32)) ((_ zero_extend 24) T1_11115)) (_ bv8 32)) ((_ zero_extend 24) T1_11114)) (_ bv8 32)) ((_ zero_extend 24) T1_11113)))
#     (bvslt T4_11113 (_ bv0 32))
#     (bvule (bvadd (bvsdiv (bvmul ?v_0 (_ bv33 32)) (_ bv100 32)) (_ bv33 32)) (_ bv100 32))
#     (bvule ?v_0 (_ bv100 32))
#     (bvule ?v_0 (_ bv0 32))
#     (not (= T4_9717 (_ bv4294967295 32)))
#     (not (= (_ bv0 32) T4_11113))
#     (bvule (_ bv0 32) T4_11113)
#     (bvult (_ bv0 32) T4_11113)
#     (= T4_9717 T4_11113)
#     (not (= T4_11113 (_ bv0 32)))
#     (= z (f T1_111979 T4_11113)))))
# (check-sat)
# (exit)
#
# Processing pair:
# Formula 1 (from ./seeds_BV_sat/bench_2603.smt2):
#
# Formula 2 (from ./seeds_BV_sat/bench_394.smt2):
#
# Fusion Result:
# (set-logic QF_BV)
# (declare-fun T1_19484 () (_ BitVec 8))
# (declare-fun T1_19414 () (_ BitVec 8))
# (declare-fun T1_19347 () (_ BitVec 8))
# (declare-fun T1_19281 () (_ BitVec 8))
# (declare-fun T1_19225 () (_ BitVec 8))
# (declare-fun T1_19221 () (_ BitVec 8))
# (declare-fun T2_18829 () (_ BitVec 16))
# (declare-fun T1_18820 () (_ BitVec 8))
# (declare-fun T2_19223 () (_ BitVec 16))
# (declare-fun T4_18821 () (_ BitVec 32))
# (declare-fun T1_19223 () (_ BitVec 8))
# (declare-fun T1_19224 () (_ BitVec 8))
# (declare-fun T1_18829 () (_ BitVec 8))
# (declare-fun T1_18830 () (_ BitVec 8))
# (declare-fun T1_18821 () (_ BitVec 8))
# (declare-fun T1_18822 () (_ BitVec 8))
# (declare-fun T1_18823 () (_ BitVec 8))
# (declare-fun T1_18824 () (_ BitVec 8))
# (declare-fun T1_10006 () (_ BitVec 8))
# (declare-fun T1_10005 () (_ BitVec 8))
# (declare-fun z () (_ BitVec 8))
# (define-fun f ((x (_ BitVec 8)) (y (_ BitVec 8))) (_ BitVec 8) (bvadd x y))
# (assert (let ((?v_17 ((_ zero_extend 24) T1_19484)) (?v_11 ((_ zero_extend 24) T1_19414)) (?v_0 ((_ zero_extend 24) (_ bv1 8))) (?v_7 ((_ zero_extend 24) T1_19347)) (?v_16 ((_ zero_extend 24) T1_19281)) (?v_15 ((_ zero_extend 24) T1_19225)) (?v_4 ((_ zero_extend 24) T1_19221)) (?v_3 ((_ zero_extend 16) T2_18829)) (?v_2 (bvsub ((_ zero_extend 24) T1_18820) (_ bv8 32)))) (let ((?v_5 (bvadd (bvadd (bvadd (bvadd (bvadd (bvadd (bvadd (bvadd ?v_2 (_ bv4286534 32)) ?v_3) (_ bv7 32)) ?v_4) (_ bv3 32)) ?v_15) ?v_0) ?v_16))) (let ((?v_9 (bvadd (bvadd ?v_5 ?v_0) ?v_7))) (let ((?v_1 (bvsub (bvadd (bvadd ?v_9 ?v_0) ?v_11) (_ bv4286503 32)))) (let ((?v_18 (bvsub (bvadd (bvadd ?v_1 (_ bv4286504 32)) ?v_17) (_ bv1 32))) (?v_19 (bvadd ?v_1 (_ bv4286576 32))) (?v_14 ((_ zero_extend 16) T2_19223)) (?v_10 (bvsub ?v_9 (_ bv4286503 32)))) (let ((?v_12 (bvsub (bvadd (bvadd ?v_10 (_ bv4286504 32)) ?v_11) (_ bv1 32))) (?v_13 (bvadd ?v_10 (_ bv4286573 32))) (?v_6 (bvsub ?v_5 (_ bv4286503 32)))) (let ((?v_8 (bvsub (bvadd (bvadd ?v_6 (_ bv4286504 32)) ?v_7) (_ bv1 32)))) (and true (= T4_18821 (bvor (bvshl (bvor (bvshl (bvor (bvshl ((_ zero_extend 24) T1_18824) (_ bv8 32)) ((_ zero_extend 24) T1_18823)) (_ bv8 32)) ((_ zero_extend 24) T1_18822)) (_ bv8 32)) ((_ zero_extend 24) T1_18821))) (= T2_18829 (bvor (bvshl ((_ zero_extend 8) T1_18830) (_ bv8 16)) ((_ zero_extend 8) T1_18829))) (= T2_19223 (bvor (bvshl ((_ zero_extend 8) T1_19224) (_ bv8 16)) ((_ zero_extend 8) T1_19223))) (= ?v_19 ?v_18) (not (= (bvadd (bvadd ?v_2 (_ bv30 32)) (_ bv4286504 32)) (_ bv0 32))) (bvult (_ bv0 32) ?v_3) (not (= ?v_3 (_ bv0 32))) (= T4_18821 ?v_3) (= ?v_4 (_ bv1 32)) (not (= ?v_14 (_ bv0 32))) (bvult (bvadd ?v_6 (_ bv4286560 32)) ?v_8) (bvult (bvadd ?v_6 (_ bv4286550 32)) ?v_8) (not (= ?v_13 ?v_12)) (bvule ?v_12 ?v_13) (= (bvadd ?v_10 (_ bv4286572 32)) ?v_12) (bvult (bvadd ?v_10 (_ bv4286560 32)) ?v_12) (bvult (bvadd ?v_10 (_ bv4286554 32)) ?v_12) (= (bvadd (bvadd (bvadd (bvadd (bvadd ?v_14 (bvsub (_ bv4294967295 32) ?v_15)) (bvsub (_ bv4294967295 32) ?v_16)) (bvsub (_ bv4294967295 32) ?v_7)) (bvsub (_ bv4294967295 32) ?v_11)) (bvsub (_ bv4294967295 32) ?v_17)) (_ bv0 32)) (bvule ?v_18 ?v_19))))))))))
# (assert (and true (bvslt (_ bv4294967295 32) (bvadd (bvashr (bvashr ((_ zero_extend 24) z) (_ bv1 32)) ((_ zero_extend 24) (_ bv2 8))) (bvshl ((_ zero_extend 24) T1_10006) ((_ zero_extend 24) (_ bv5 8)))))))
# (check-sat)
# (exit)
#
#
# Valid Fused Formulas: 47
#
# SAT Fused Formulas: 47
#
# UNSAT Fused Formulas: 0
#
# Fused Formulas with Errors: 3
#
# Results saved to fused_results_sat.csv

# %%
from validate_SMT import validate_and_solve_smt
formula1 = """

"""


formula2 = """

"""

response = get_new_chain().invoke({
    "formula1": formula1,
    "formula2": formula2
})

print(response.content + '\n')
print(validate_and_solve_smt(response.content))
